# %%
import pandas as pd

# %% [markdown]
# #### **TF-IDF**

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

df = pd.read_csv('item_pool.csv')

question = '가장 큰 수와 가장 작은 수의 곱을 구하시오. 309 54 91 636'

vectorizer = TfidfVectorizer()

X = vectorizer.fit_transform(df['question'])
Y = vectorizer.transform([question])

cosine_sim = cosine_similarity(Y, X)
cosine_sim = cosine_sim.flatten()

df['cosine_sim'] = cosine_sim
df = df.sort_values(by='cosine_sim', ascending=False)

# %%
df.head(5)
# Out:
#     grade  semester    chapter                                       question  \
# 33      3         1     3. 나눗셈              다음 중 몫과 나머지의 합이 가장 작은 것은 어느 것인가요?
# 42      3         1      4. 곱셈  □ 안에 들어갈 수 있는 수 중에서 가장 작은 수는 얼마인가요? 153×□＞800
# 9       3         2      4. 분수                           길이가 가장 긴 것은 어느 것입니까?
# 5       3         2  5. 들이와 무게                          들이가 가장 많은 것은 어느 것입니까?
# 14      3         1    2. 평면도형            ‘두 점 사이를 곧게 이은 가장 짧은 선’을 무엇이라고 합니까?
#
#            s1         s2         s3         s4          s5 answer  difficulty  \
# 33       76÷3       57÷2      126÷5      127÷4       132÷6      5           0
# 42          5          6          7          8           9      2           1
# 9   36cm의 2/3  36cm의 1/4  36cm의 5/6  36cm의 7/9  36cm의 7/12      3           2
# 5      1080mL   10L 80mL   1L 800mL        18L   10L 800mL      4           2
# 14        꼭지점         직선          변         선분           각      4           2
#
# ...

# %% [markdown]
# ### **Word2Vec** ##

# %%
import numpy as np
from gensim.models import Word2Vec
from sklearn.metrics.pairwise import cosine_similarity

model = Word2Vec.load('word2vec.model')

question = '가장 큰 수와 가장 작은 수의 곱을 구하시오. 309 54 91 636'

def document_vector(model, doc):
