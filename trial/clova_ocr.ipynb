# %%
import requests
import uuid
import time
import json

# %%
api_url = 'https://mhkbp2mf6p.apigw.ntruss.com/custom/v1/30558/e613bb442bf089c035920266fa19f94a0972c896f212eda804d265c3b3f0e3f9/general'
secret_key = 'cmNvY1FkUWZYaVFnZEpkSEVXdElSd1JYQVhzeUF6WnY='

# %%
image_file = 'sample_item/sample1.png'

# %%
request_json = {
    'images': [
        {
            'format': 'jpg',
            'name': 'demo'
        }
    ],
    'requestId': str(uuid.uuid4()),
    'version': 'V2',
    'timestamp': int(round(time.time() * 1000))
}

 
payload = {'message': json.dumps(request_json).encode('UTF-8')}
files = [
  ('file', open(image_file,'rb'))
]
headers = {
  'X-OCR-SECRET': secret_key
}

response = requests.request("POST", api_url, headers=headers, data = payload, files = files)

print(response.text.encode('utf8'))
# Out:
# b'{"version":"V2","requestId":"394aa1fa-6d4c-4794-a844-28c7dd0a039b","timestamp":1716194448502,"images":[{"uid":"ccd1943158744f4bbdb1e9c72c13087a","name":"demo","inferResult":"SUCCESS","message":"SUCCESS","validationResult":{"result":"NO_REQUESTED"},"convertedImageInfo":{"width":966,"height":402,"pageIndex":0,"longImage":false},"fields":[{"valueType":"ALL","boundingPoly":{"vertices":[{"x":28.0,"y":41.0},{"x":62.0,"y":41.0},{"x":62.0,"y":73.0},{"x":28.0,"y":73.0}]},"inferText":"1.","inferConfidence":0.9999,"type":"NORMAL","lineBreak":false},{"valueType":"ALL","boundingPoly":{"vertices":[{"x":78.0,"y":36.0},{"x":222.0,"y":36.0},{"x":222.0,"y":76.0},{"x":78.0,"y":76.0}]},"inferText":"\xed\x98\x95\xeb\xaf\xbc\xec\x9d\xb4\xeb\x84\xa4","inferConfidence":0.9996,"type":"NORMAL","lineBreak":false},{"valueType":"ALL","boundingPoly":{"vertices":[{"x":237.0,"y":36.0},{"x":381.0,"y":36.0},{"x":381.0,"y":76.0},{"x":237.0,"y":76.0}]},"inferText":"\xeb\x86\x8d\xec\x9e\xa5\xec\x97\x90\xec\x84\x9c","inferConfidence":1.0,"type":"NORMAL","lineBreak":false},{"valueType":"ALL","boundingPoly":{"vertices":[{"x":398.0,"y":37.0},{"x":793.0,"y":37.0},{"x":793.0,"y":76.0},{"x":398.0,"y":76.0}]},"inferText":"\xec\x98\xa4\xeb\x8a\x98 \xeb\x94\xb4 \xea\xb7\xa4\xec\x9d\x80\xed\x95\x9c \xec\x83\x81\xec\x9e\x90\xec\x97\x90","inferConfidence":0.9807,"type":"NORMAL","lineBreak":false},{"valueType":"ALL","boundingPoly":{"vertices":[{"x":808.0,"y":35.0},{"x":944.0,"y":37.0},{"x":943.0,"y":77.0},{"x":808.0,"y":76.0}]},"inferText":"100\xea\xb0\x9c\xec\x94\xa9","inferConfidence":0.9999,"type":"NORMAL","lineBreak":true},{"valueType":"ALL","boundingPoly":{"vertices":[{"x":25.0,"y":94.0},{"x":179.0,"y":94.0},{"x":179.0,"y":134.0},{"x":25.0,"y":134.0}]},"inferText":"74\xec\x83\x81\xec\x9e\x90\xec\x99\x80","inferConfidence":0.9998,"type":"NORMAL","lineBreak":false},{"valueType":"ALL","boundingPoly":{"vertices":[{"x":191.0,"y":93.0},{"x":267.0,"y":93.0},{"x":267.0,"y":134.0},{"x":191.0,"y":134.0}]},"inferText":"\xeb\x82\xb1\xea\xb0\x9c","inferConfidence":1.0,"type":"NORMAL","lineBreak":false},{"valueType":"ALL","boundingPoly":{"vertices":[{"x":282.0,"y":94.0},{"x":482.0,"y":94.0},{"x":482.0,"y":134.0},{"x":282.0,"y":134.0}]},"inferText":"15\xea\xb0\x9c\xec\x9e\x85\xeb\x8b\x88\xeb\x8b\xa4.","inferConfidence":0.9999,"type":"NORMAL","lineBreak":false},{"valueType":"ALL","boundingPoly":{"vertices":[{"x":495.0,"y":93.0},{"x":573.0,"y":93.0},{"x":573.0,"y":134.0},{"x":495.0,"y":134.0}]},"inferText":"\xec\x98\xa4\xeb\x8a\x98","inferConfidence":1.0,"type":"NORMAL","lineBreak":false},{"valueType":"ALL","boundingPoly":{"vertices":[{"x":585.0,"y":96.0},{"x":625.0,"y":96.0},{"x":625.0,"y":131.0},{"x":585.0,"y":131.0}]},"inferText":"\xeb\x94\xb4","inferConfidence":0.9995,"type":"NORMAL","lineBreak":false},{"valueType":"ALL","boundingPoly":{"vertices":[{"x":637.0,"y":95.0},{"x":712.0,"y":95.0},{"x":712.0,"y":132.0},{"x":637.0,"y":132.0}]},"inferText":"\xea\xb7\xa4\xec\x9d\x80","inferConfidence":0.9972,"type":"NORMAL","lineBreak":false},{"valueType":"ALL","boundingPoly":{"vertices":[{"x":727.0,"y":92.0},{"x":805.0,"y":93.0},{"x":804.0,"y":134.0},{"x":726.0,"y":133.0}]},"inferText":"\xeb\xaa\xa8\xeb\x91\x90","inferConfidence":1.0,"type":"NORMAL","lineBreak":false},{"valueType":"ALL","boundingPoly":{"vertices":[{"x":817.0,"y":93.0},{"x":944.0,"y":93.0},{"x":944.0,"y":134.0},{"x":817.0,"y":134.0}]},"inferText":"\xeb\xaa\x87 \xea\xb0\x9c\xec\x9e\x85","inferConfidence":0.9784,"type":"NORMAL","lineBreak":true},{"valueType":"ALL","boundingPoly":{"vertices":[{"x":28.0,"y":151.0},{"x":122.0,"y":151.0},{"x":122.0,"y":190.0},{"x":28.0,"y":190.0}]},"inferText":"\xeb\x8b\x88\xea\xb9\x8c?","inferConfidence":1.0,"type":"NORMAL","lineBreak":true},{"valueType":"ALL","boundingPoly":{"vertices":[{"x":37.0,"y":272.0},{"x":56.0,"y":272.0},{"x":56.0,"y":298.0},{"x":37.0,"y":298.0}]},"inferText":"1","inferConfidence":1.0,"type":"NORMAL","lineBreak":false},{"valueType":"ALL","boundingPoly":{"vertices":[{"x":75. ...

# %%
response1 = json.loads(response.text)
response1
# Out:
# {'version': 'V2',
#  'requestId': '394aa1fa-6d4c-4794-a844-28c7dd0a039b',
#  'timestamp': 1716194448502,
#  'images': [{'uid': 'ccd1943158744f4bbdb1e9c72c13087a',
#    'name': 'demo',
#    'inferResult': 'SUCCESS',
#    'message': 'SUCCESS',
#    'validationResult': {'result': 'NO_REQUESTED'},
#    'convertedImageInfo': {'width': 966,
#     'height': 402,
#     'pageIndex': 0,
#     'longImage': False},
#    'fields': [{'valueType': 'ALL',
#      'boundingPoly': {'vertices': [{'x': 28.0, 'y': 41.0},
#        {'x': 62.0, 'y': 41.0},
#        {'x': 62.0, 'y': 73.0},
#        {'x': 28.0, 'y': 73.0}]},
#      'inferText': '1.',
#      'inferConfidence': 0.9999,
#      'type': 'NORMAL',
#      'lineBreak': False},
#     {'valueType': 'ALL',
#      'boundingPoly': {'vertices': [{'x': 78.0, 'y': 36.0},
#        {'x': 222.0, 'y': 36.0},
#        {'x': 222.0, 'y': 76.0},
#        {'x': 78.0, 'y': 76.0}]},
#      'inferText': '형민이네',
#      'inferConfidence': 0.9996,
#      'type': 'NORMAL',
#      'lineBreak': False},
#     {'valueType': 'ALL',
#      'boundingPoly': {'vertices': [{'x': 237.0, 'y': 36.0},
#        {'x': 381.0, 'y': 36.0},
#        {'x': 381.0, 'y': 76.0},
#        {'x': 237.0, 'y': 76.0}]},
#      'inferText': '농장에서',
#      'inferConfidence': 1.0,
#      'type': 'NORMAL',
#      'lineBreak': False},
#     {'valueType': 'ALL',
#      'boundingPoly': {'vertices': [{'x': 398.0, 'y': 37.0},
#        {'x': 793.0, 'y': 37.0},
#        {'x': 793.0, 'y': 76.0},
#        {'x': 398.0, 'y': 76.0}]},
#      'inferText': '오늘 딴 귤은한 상자에',
#      'inferConfidence': 0.9807,
#      'type': 'NORMAL',
#      'lineBreak': False},
#     {'valueType': 'ALL',
#      'boundingPoly': {'vertices': [{'x': 808.0, 'y': 35.0},
#        {'x': 944.0, 'y': 37.0},
#        {'x': 943.0, 'y': 77.0},
#        {'x': 808.0, 'y': 76.0}]},
#      'inferText': '100개씩',
#      'inferConfidence': 0.9999,
#      'type': 'NORMAL',
#      'lineBreak': True},
#     {'valueType': 'ALL',
#      'boundingPoly': {'vertices': [{'x': 25.0, 'y': 94.0},
#        {'x': 179.0, 'y': 94.0},
#        {'x': 179.0, 'y': 134.0},
#        {'x': 25.0, 'y': 134.0}]},
#      'inferText': '74상자와',
#      'inferConfidence': 0.9998,
#      'type': 'NORMAL',
#      'lineBreak': False},
#     {'valueType': 'ALL',
#      'boundingPoly': {'vertices': [{'x': 191.0, 'y': 93.0},
#        {'x': 267.0, 'y': 93.0},
#        {'x': 267.0, 'y': 134.0},
#        {'x': 191.0, 'y': 134.0}]},
#      'inferText': '낱개',
#      'inferConfidence': 1.0,
#      'type': 'NORMAL',
#      'lineBreak': False},
#     {'valueType': 'ALL',
#      'boundingPoly': {'vertices': [{'x': 282.0, 'y': 94.0},
#        {'x': 482.0, 'y': 94.0},
#        {'x': 482.0, 'y': 134.0},
#        {'x': 282.0, 'y': 134.0}]},
#      'inferText': '15개입니다.',
#      'inferConfidence': 0.9999,
#      'type': 'NORMAL',
#      'lineBreak': False},
#     {'valueType': 'ALL',
#      'boundingPoly': {'vertices': [{'x': 495.0, 'y': 93.0},
#        {'x': 573.0, 'y': 93.0},
#        {'x': 573.0, 'y': 134.0},
#        {'x': 495.0, 'y': 134.0}]},
#      'inferText': '오늘',
#      'inferConfidence': 1.0,
#      'type': 'NORMAL',
#      'lineBreak': False},
#     {'valueType': 'ALL',
#      'boundingPoly': {'vertices': [{'x': 585.0, 'y': 96.0},
#        {'x': 625.0, 'y': 96.0},
#        {'x': 625.0, 'y': 131.0},
#        {'x': 585.0, 'y': 131.0}]},
#      'inferText': '딴',
#      'inferConfidence': 0.9995,
#      'type': 'NORMAL',
#      'lineBreak': False},
#     {'valueType': 'ALL',
#      'boundingPoly': {'vertices': [{'x': 637.0, 'y': 95.0},
#        {'x': 712.0, 'y': 95.0},
#        {'x': 712.0, 'y': 132.0},
#        {'x': 637.0, 'y': 132.0}]},
#      'inferText': '귤은',
#      'inferConfidence': 0.9972,
#      'type': 'NORMAL',
#      'lineBreak': False},
#     {'valueType': 'ALL',
#      'boundingPoly': {'vertices': [{'x': 727.0, 'y': 92.0},
#        {'x': 805.0, 'y': 93.0},
#        {'x': 804.0, 'y': 134.0},
#        {'x': 726.0, 'y': 133.0}]},
#      'inferText': '모두',
#      'inferConfidence': 1.0,
#      'type': 'NORMAL',
#      'lineBreak': False},
#     {'valueType': 'ALL',
#      'boundingPoly': {'vertices': [{'x': 817.0, 'y': 93.0},
#        {'x': 944.0, 'y': 93.0},
#        {'x': 944.0, 'y': 134.0},
#        {'x': 817.0, 'y': 134.0}]},
#      'inferText': '몇 개입',
#      'inferConfidence': 0.9784,
#      'type': 'NORMAL',
#      'lineBreak': True},
#     {'valueType': 'ALL',
#      'boundingPoly': {'vertices': [{'x': 28.0, 'y': 151.0},
#        {'x': 122.0, 'y': 151.0},
#        {'x': 122.0, 'y': 190.0},
#        {'x': 28.0, 'y': 190.0}]},
#      'inferText': '니까?',
#      'inferConfidence': 1.0,
#      'type': 'NORMAL',
#      'lineBreak': True},
#     {'valueType': 'ALL',
#      'boundingPoly': {'vertices': [{'x': 37.0, 'y': 272.0},
#        {'x': 56.0, 'y': 272.0},
#        {'x': 56.0, 'y': 298.0},
#        {'x': 37.0, 'y': 298.0}]},
#      'inferText': '1',
#      'inferConfidence': 1.0,
#      'type': 'NORMAL',
#      'lineBreak': False},
#     {'valueType': 'ALL',
#      'boundingPoly': {'vertices': [{'x': 75.0, 'y': 267.0},
#        {'x': 167.0, 'y': 267.0},
#        {'x': 167.0, 'y': 304.0},
#        {'x': 75.0, 'y': 304.0}]},
#      'inferText': '7400',
#      'inferConfidence': 1.0,
#      'type': 'NORMAL',
#      'lineBreak': False},
#     {'valueType': 'ALL',
#      'boundingPoly': {'vertices': [{'x': 386.0, 'y': 271.0},
#        {'x': 406.0, 'y': 271.0},
#        {'x': 406.0, 'y': 298.0},
#        {'x': 386.0, 'y': 298.0}]},
#      'inferText': '2',
#      'inferConfidence': 1.0,
#      'type': 'NORMAL',
#      'lineBreak': False},
#     {'valueType': 'ALL',
#      'boundingPoly': {'vertices': [{'x': 426.0, 'y': 267.0},
#        {'x': 517.0, 'y': 267.0},
#        {'x': 517.0, 'y': 303.0},
#        {'x': 426.0, 'y': 303.0}]},
#      'inferText': '7375',
#      'inferConfidence': 1.0,
#      'type': 'NORMAL',
#      'lineBreak': False},
#     {'valueType': 'ALL',
#      'boundingPoly': {'vertices': [{'x': 733.0, 'y': 271.0},
#        {'x': 755.0, 'y': 271.0},
#        {'x': 755.0, 'y': 298.0},
#        {'x': 733.0, 'y': 298.0}]},
#      'inferText': '3',
#      'inferConfidence': 1.0,
#      'type': 'NORMAL',
#      'lineBreak': False},
#     {'valueType': 'ALL',
#      'boundingPoly': {'vertices': [{'x': 775.0, 'y': 267.0},
#        {'x': 864.0, 'y': 267.0},
#        {'x': 864.0, 'y': 302.0},
#        {'x': 775.0, 'y': 302.0}]},
#      'inferText': '7410',
#      'inferConfidence': 1.0,
#      'type': 'NORMAL',
#      'lineBreak': True},
#     {'valueType': 'ALL',
#      'boundingPoly': {'vertices': [{'x': 35.0, 'y': 329.0},
#        {'x': 57.0, 'y': 329.0},
#        {'x': 57.0, 'y': 354.0},
#        {'x': 35.0, 'y': 354.0}]},
#      'inferText': '4',
#      'inferConfidence': 0.9995,
#      'type': 'NORMAL',
#      'lineBreak': False},
#     {'valueType': 'ALL',
#      'boundingPoly': {'vertices': [{'x': 78.0, 'y': 324.0},
#        {'x': 166.0, 'y': 324.0},
#        {'x': 166.0, 'y': 360.0},
#        {'x': 78.0, 'y': 360.0}]},
#      'inferText': '7405',
#      'inferConfidence': 1.0,
#      'type': 'NORMAL',
#      'lineBreak': False},
#     {'valueType': 'ALL',
#      'boundingPoly': {'vertices': [{'x': 386.0, 'y': 329.0},
#        {'x': 405.0, 'y': 329.0},
#        {'x': 405.0, 'y': 354.0},
#        {'x': 386.0, 'y': 354.0}]},
#      'inferText': '5',
#      'inferConfidence': 1.0,
#      'type': 'NORMAL',
#      'lineBreak': False},
#     {'valueType': 'ALL',
#      'boundingPoly': {'vertices': [{'x': 426.0, 'y': 324.0},
#        {'x': 516.0, 'y': 324.0},
#        {'x': 516.0, 'y': 360.0},
#        {'x': 426.0, 'y': 360.0}]},
#      'inferText': '7415',
#      'inferConfidence': 1.0,
#      'type': 'NORMAL',
#      'lineBreak': True}]}]}

# %%
response1 = json.loads(response.text)
inferText_list = [field['inferText'] for field in response1['images'][0]['fields']]
sentence = ' '.join([str(text) for text in inferText_list])
print(sentence)
# Out:
# 1. 형민이네 농장에서 오늘 딴 귤은한 상자에 100개씩 74상자와 낱개 15개입니다. 오늘 딴 귤은 모두 몇 개입 니까? 1 7400 2 7375 3 7410 4 7405 5 7415
